# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("C:/Users/asus/Desktop/Data Visualization/Homeworks/HW2/lung_cancer_prediction_dataset.csv")
data2 = pd.read_csv("C:/Users/asus/Desktop/Data Visualization/Homeworks/HW2/global_air_pollution_dataset.csv")

# %%
data1.head()
# Out:
#    ID       Country  Population_Size  Age  Gender Smoker  Years_of_Smoking  \
# 0   0         China             1400   80    Male    Yes                30
# 1   1          Iran               84   53    Male     No                 0
# 2   2        Mexico              128   47    Male    Yes                12
# 3   3     Indonesia              273   39  Female     No                 0
# 4   4  South Africa               59   44  Female     No                 0
#
#    Cigarettes_per_Day Passive_Smoker Family_History  ...  \
# 0                  29             No             No  ...
# 1                   0            Yes             No  ...
# 2                   6            Yes             No  ...
# 3                   0             No            Yes  ...
# 4                   0            Yes             No  ...
#
#   Air_Pollution_Exposure Occupational_Exposure  Indoor_Pollution  \
# 0                    Low                   Yes                No
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220632 entries, 0 to 220631
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ID                           220632 non-null  int64
#  1   Country                      220632 non-null  object
#  2   Population_Size              220632 non-null  int64
#  3   Age                          220632 non-null  int64
#  4   Gender                       220632 non-null  object
#  5   Smoker                       220632 non-null  object
#  6   Years_of_Smoking             220632 non-null  int64
#  7   Cigarettes_per_Day           220632 non-null  int64
#  8   Passive_Smoker               220632 non-null  object
#  9   Family_History               220632 non-null  object
#  10  Lung_Cancer_Diagnosis        220632 non-null  object
#  11  Cancer_Stage                 8961 non-null    object
# ...

# %%
plt.title('Boxplot of Lung Cancer Deaths Distribution')
plt.boxplot(data1['Annual_Lung_Cancer_Deaths']); 
plt.xlabel('Annual_Lung_Cancer_Deaths')
plt.show();

# %%
data2.head()
# Out:
#               Country              City  AQI_Value AQI_Category  CO_AQI_Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO_AQI_Category  Ozone_AQI_Value Ozone_AQI_Category  NO2_AQI_Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2_AQI_Category  PM2.5_AQI_Value PM2.5_AQI_Category
# ...

# %%
plt.hist(data2['PM2.5_AQI_Value'],  bins=30, edgecolor='black')
plt.xlabel('PM2.5 AQI Values')
plt.ylabel('Count')
plt.title('Histogram of PM2.5 AQI Values')
plt.show()

# %%
sns.kdeplot(data = data1, x='Mortality_Rate', fill=True)
plt.xlabel('Mortality Rate')
plt.title('Density Plot of the lung Cancer Martality Rate')
plt.show()

# %%
# Create the figure with white background
plt.figure(figsize=(10, 6))

# Set the background color of the axes (where the plot is)
plt.gca().set_facecolor('lightgrey')

# Add only horizontal gridlines (with zorder to ensure gridlines stay in the background)
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5, color='white', zorder=0)

# Plot the histogram with lines around bins (with zorder to bring it to the front)
plt.hist(data2['PM2.5_AQI_Value'], bins=30, density=True, alpha=0.6, color='blue', edgecolor='black', linewidth=1.2, label='Histogram', zorder=3)

# Plot the density plot (KDE) with color below the curve (with zorder to bring it to the front)
sns.kdeplot(data2['PM2.5_AQI_Value'], color='red', linewidth=2.5, fill=True, alpha=0.4, label='Density Plot (KDE)', zorder=3)

# Add labels and title with bold font
plt.title('PM2.5 AQI Distribution with Density Overlay', fontsize=16, fontweight="bold")
plt.xlabel('PM2.5 AQI Value', fontsize=14, fontweight="bold")
plt.ylabel('Density', fontsize=14, fontweight="bold")
plt.legend(fontsize=12)

# Remove the y-axis line and ticks
plt.gca().spines['left'].set_visible(False)
plt.gca().tick_params(axis='y', length=0)

# Remove top, right, and bottom borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

# Add the descriptive line at the bottom left
plt.figtext(0.05, -0.08, "This plot represents the distribution of PM2.5 AQI values with a density overlay.", 
            ha="left", fontsize=12, color="black")

# Show the plot
plt.tight_layout()  # Ensure the text doesn't overlap with the plot
plt.show()
